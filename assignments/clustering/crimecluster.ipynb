# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("crime_data.csv")
df = data.copy()
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# 17       Louisiana    15.4      249        66  22.2
# 18           Maine     2.1       83        51   7.8
# 19        Maryland    11.3      300        67  27.8
# 20   Massachusetts     4.4      149        85  16.3
# 21        Michigan    12.1      255        74  35.1
# 22       Minnesota     2.7       72        66  14.9
# 23     Mississippi    16.1      259        44  17.1
# 24        Missouri     9.0      178        70  28.2
# 25         Montana     6.0      109        53  16.4
# 26        Nebraska     4.3      102        62  16.5
# 27          Nevada    12.2      252        81  46.0
# 28   New Hampshire     2.1       57        56   9.5
# 29      New Jersey     7.4      159        89  18.8
# 30      New Mexico    11.4      285        70  32.1
# 31        New York    11.1      254        86  26.1
# 32  North Carolina    13.0      337        45  16.1
# 33    North Dakota     0.8       45        44   7.3
# 34            Ohio     7.3      120        75  21.4
# 35        Oklahoma     6.6      151        68  20.0
# 36          Oregon     4.9      159        67  29.3
# 37    Pennsylvania     6.3      106        72  14.9
# 38    Rhode Island     3.4      174        87   8.3
# 39  South Carolina    14.4      279        48  22.5
# 40    South Dakota     3.8       86        45  12.8
# 41       Tennessee    13.2      188        59  26.9
# 42           Texas    12.7      201        80  25.5
# 43            Utah     3.2      120        80  22.9
# 44         Vermont     2.2       48        32  11.2
# 45        Virginia     8.5      156        63  20.7
# 46      Washington     4.0      145        73  26.2
# 47   West Virginia     5.7       81        39   9.3
# 48       Wisconsin     2.6       53        66  10.8
# 49         Wyoming     6.8      161        60  15.6

# %% [markdown]
# ### Lets understand the Data first

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     object
#  1   Murder      50 non-null     float64
#  2   Assault     50 non-null     int64
#  3   UrbanPop    50 non-null     int64
#  4   Rape        50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# Murder        0
# Assault       0
# UrbanPop      0
# Rape          0
# dtype: int64

# %% [markdown]
# Lets rename first column for better understanding in future

# %%
df.rename(columns={"Unnamed: 0": "States"}, inplace = True)

# %% [markdown]
# Lets plot the data to get more insights

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize = (16,10), dpi = 50)
df.hist(ax = ax , alpha = 0.5)
plt.show()
# Out:
# /tmp/ipykernel_283461/1640560710.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist(ax = ax , alpha = 0.5)

# %% [markdown]
# ### Lets check do we need to apply any transformation or not

# %%
sns.pairplot(df, kind= 'reg', diag_kind='kde')
# Out:
# /home/its_relative/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Applying log transformation

# %%
import seaborn as sns
import numpy as np

# Assuming 'df' is your DataFrame
numerical_cols = df.select_dtypes(include=np.number).columns

# Apply square root transformation to numerical columns
df_sqrt_transformed = df.copy()
df_sqrt_transformed[numerical_cols] = df[numerical_cols].apply(lambda x: np.log(x+1))

# Create pairplot with regression plots and kernel density estimates
sns.pairplot(df_sqrt_transformed, kind="reg", diag_kind="kde")
# Out:
# /home/its_relative/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# no the log transformation doesn't feel effective enough

# %%
import seaborn as sns
import numpy as np

# Assuming 'df' is your DataFrame
numerical_cols = df.select_dtypes(include=np.number).columns

# Apply square root transformation to numerical columns
df_sqrt_transformed = df.copy()
df_sqrt_transformed[numerical_cols] = df[numerical_cols].apply(lambda x: np.sqrt(x))

# Create pairplot with regression plots and kernel density estimates
sns.pairplot(df_sqrt_transformed, kind="reg", diag_kind="kde")
# Out:
# /home/its_relative/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# sqrt was able to make it look like a normal bell shaped curve

# %% [markdown]
# ### Lets check for Outliers

# %% [markdown]
# #### one at a time

# %%
fig, axes = plt.subplots(nrows=len(numerical_cols), figsize=(10, 6 * len(numerical_cols)))

for i, col in enumerate(numerical_cols):
    df.boxplot(column=col, ax=axes[i])
    axes[i].set_title(f'Boxplot for {col}')

plt.show()

# %% [markdown]
# so it is clearly visible that only the rape category has got an outlier

# %% [markdown]
# #### on same scale

# %%
plt.subplots(figsize = (16,9), dpi = 50)
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# lets transform the data with sqrt and then continue it

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   States    50 non-null     object
#  1   Murder    50 non-null     float64
#  2   Assault   50 non-null     int64
#  3   UrbanPop  50 non-null     int64
#  4   Rape      50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
con_cols = [col for col in df.columns if df[col].dtype != "object"]
cat_cols = [col for col in df.columns if df[col].dtype == "object"]

# %%
con_cols
# Out:
# ['Murder', 'Assault', 'UrbanPop', 'Rape']

# %%
cat_cols
# Out:
# ['States']

# %% [markdown]
# lets apply sqrt transformation to the continuous columns in the dataframe

# %%
dfSqrt = df.copy()
dfSqrt[con_cols] = df[con_cols].apply(lambda x: np.sqrt(x))

# %%
dfSqrt
# Out:
#             States    Murder    Assault  UrbanPop      Rape
# 0          Alabama  3.633180  15.362291  7.615773  4.604346
# 1           Alaska  3.162278  16.217275  6.928203  6.670832
# 2          Arizona  2.846050  17.146428  8.944272  5.567764
# 3         Arkansas  2.966479  13.784049  7.071068  4.415880
# 4       California  3.000000  16.613248  9.539392  6.371813
# 5         Colorado  2.810694  14.282857  8.831761  6.220932
# 6      Connecticut  1.816590  10.488088  8.774964  3.331666
# 7         Delaware  2.428992  15.427249  8.485281  3.974921
# 8          Florida  3.924283  18.303005  8.944272  5.648008
# 9          Georgia  4.171331  14.525839  7.745967  5.079370
# 10          Hawaii  2.302173   6.782330  9.110434  4.494441
# 11           Idaho  1.612452  10.954451  7.348469  3.768289
# 12        Illinois  3.224903  15.779734  9.110434  4.898979
# 13         Indiana  2.683282  10.630146  8.062258  4.582576
# 14            Iowa  1.483240   7.483315  7.549834  3.361547
# 15          Kansas  2.449490  10.723805  8.124038  4.242641
# 16        Kentucky  3.114482  10.440307  7.211103  4.037326
# 17       Louisiana  3.924283  15.779734  8.124038  4.711688
# 18           Maine  1.449138   9.110434  7.141428  2.792848
# 19        Maryland  3.361547  17.320508  8.185353  5.272571
# 20   Massachusetts  2.097618  12.206556  9.219544  4.037326
# 21        Michigan  3.478505  15.968719  8.602325  5.924525
# 22       Minnesota  1.643168   8.485281  8.124038  3.860052
# 23     Mississippi  4.012481  16.093477  6.633250  4.135215
# 24        Missouri  3.000000  13.341664  8.366600  5.310367
# 25         Montana  2.449490  10.440307  7.280110  4.049691
# 26        Nebraska  2.073644  10.099505  7.874008  4.062019
# 27          Nevada  3.492850  15.874508  9.000000  6.782330
# 28   New Hampshire  1.449138   7.549834  7.483315  3.082207
# 29      New Jersey  2.720294  12.609520  9.433981  4.335897
# 30      New Mexico  3.376389  16.881943  8.366600  5.665686
# 31        New York  3.331666  15.937377  9.273618  5.108816
# 32  North Carolina  3.605551  18.357560  6.708204  4.012481
# 33    North Dakota  0.894427   6.708204  6.633250  2.701851
# 34            Ohio  2.701851  10.954451  8.660254  4.626013
# 35        Oklahoma  2.569047  12.288206  8.246211  4.472136
# 36          Oregon  2.213594  12.609520  8.185353  5.412947
# 37    Pennsylvania  2.509980  10.295630  8.485281  3.860052
# 38    Rhode Island  1.843909  13.190906  9.327379  2.880972
# 39  South Carolina  3.794733  16.703293  6.928203  4.743416
# 40    South Dakota  1.949359   9.273618  6.708204  3.577709
# 41       Tennessee  3.633180  13.711309  7.681146  5.186521
# 42           Texas  3.563706  14.177447  8.944272  5.049752
# 43            Utah  1.788854  10.954451  8.944272  4.785394
# 44         Vermont  1.483240   6.928203  5.656854  3.346640
# 45        Virginia  2.915476  12.489996  7.937254  4.549725
# 46      Washington  2.000000  12.041595  8.544004  5.118594
# 47   West Virginia  2.387467   9.000000  6.244998  3.049590
# 48       Wisconsin  1.612452   7.280110  8.124038  3.286335
# 49         Wyoming  2.607681  12.688578  7.745967  3.949684

# %% [markdown]
# ### Lets scale the data

# %%
con_cols
# Out:
# ['Murder', 'Assault', 'UrbanPop', 'Rape']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

dfSqrt[con_cols] = sc.fit_transform(dfSqrt[con_cols])

# %%
dfSqrt = dfSqrt.set_index("States")

# %%
from sklearn.cluster import KMeans
wss = []
for i in range(2,16):
    km = KMeans(n_clusters=i)
    km.fit(dfSqrt.iloc[:,1:]) # Because in the question it has been asked to take only top 3 PCA's.
    wss.append(km.inertia_)
# Out:
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.plot(range(2,16),wss)

# %% [markdown]
# Seems to me that 4 is the optimum number of clusters

# %% [markdown]
# ### Lets Build the Model with the information acquired till now

# %%
km  = KMeans(n_clusters= 4, random_state=42)
cluster_pred = km.fit_predict(dfSqrt)
# Out:
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
cluster_pred
# Out:
# array([1, 1, 2, 1, 2, 2, 3, 3, 2, 1, 3, 0, 2, 3, 0, 3, 3, 1, 0, 2, 3, 2,
#        0, 1, 2, 3, 3, 2, 0, 3, 2, 2, 1, 0, 3, 3, 3, 3, 3, 1, 0, 1, 2, 3,
#        0, 3, 3, 0, 0, 3], dtype=int32)

# %%
dfKmeans = dfSqrt.copy()

# %%
dfKmeans["Cluster"] = cluster_pred

# %% [markdown]
# Adding 1 to all cluster numbers because lets be real here 'cluster 0' naah, seems a bit odd.

# %%
dfKmeans["Cluster"] = dfKmeans["Cluster"].apply(lambda x: x+1)

# %%
dfKmeans
# Out:
#                   Murder   Assault  UrbanPop      Rape  Cluster
# States
# Alabama         1.191064  0.825024 -0.470119  0.105167        2
# Alaska          0.607966  1.084703 -1.224569  2.192878        2
# Arizona         0.216395  1.366910  0.987602  1.078481        3
# Arkansas        0.365517  0.345672 -1.067808 -0.085234        2
# California      0.407024  1.204970  1.640610  1.890787        3
# Colorado        0.172615  0.497173  0.864147  1.738357        3
# Connecticut    -1.058340 -0.655392  0.801826 -1.180584        4
# Delaware       -0.300030  0.844753  0.483966 -0.530722        4
# Florida         1.551524  1.718190  0.987602  1.159549        3
# Georgia         1.857432  0.570972 -0.327262  0.585070        2
# Hawaii         -0.457064 -1.780922  1.169927 -0.005866        4
# Idaho          -1.311116 -0.513746 -0.763424 -0.739477        1
# Illinois        0.685512  0.951811  1.169927  0.402827        3
# Indiana         0.014846 -0.612245  0.019795  0.083174        4
# Iowa           -1.471113 -1.568015 -0.542472 -1.150396        1
# Kansas         -0.274648 -0.583799  0.087585 -0.260253        4
# Kentucky        0.548783 -0.669904 -0.914152 -0.467676        4
# Louisiana       1.551524  0.951811  0.087585  0.213612        2
# Maine          -1.513340 -1.073819 -0.990603 -1.724936        1
# Maryland        0.854712  1.419782  0.154863  0.780255        3
# Massachusetts  -0.710356 -0.133451  1.289651 -0.467676        4
# Michigan        0.999537  1.009211  0.612395  1.438906        3
# Minnesota      -1.273082 -1.263693  0.087585 -0.646771        1
# Mississippi     1.660734  1.047102 -1.548212 -0.368782        2
# Missouri        0.407024  0.211309  0.353741  0.818440        3
# Montana        -0.274648 -0.669904 -0.838432 -0.455184        4
# Nebraska       -0.740042 -0.773414 -0.186766 -0.442729        4
# Nevada          1.017299  0.980596  1.048751  2.305521        3
# New Hampshire  -1.513340 -1.547812 -0.615462 -1.432605        1
# New Jersey      0.060677 -0.011061  1.524945 -0.166039        4
# New Mexico      0.873090  1.286579  0.353741  1.177408        3
# New York        0.817712  0.999691  1.348984  0.614819        3
# North Carolina  1.156852  1.734760 -1.465967 -0.492777        2
# North Dakota   -2.200214 -1.803435 -1.548212 -1.816867        1
# Ohio            0.037840 -0.513746  0.675958  0.127057        4
# Oklahoma       -0.126606 -0.108652  0.221642 -0.028400        4
# Oregon         -0.566747 -0.011061  0.154863  0.922074        4
# Pennsylvania   -0.199746 -0.713846  0.483966 -0.646771        4
# Rhode Island   -1.024513  0.165520  1.407974 -1.635907        4
# South Carolina  1.391108  1.232319 -1.224569  0.245666        2
# South Dakota   -0.893938 -1.024256 -1.465967 -0.932014        1
# Tennessee       1.191064  0.323580 -0.398388  0.693322        2
# Texas           1.105037  0.465157  0.987602  0.555149        3
# Utah           -1.092684 -0.513746  0.987602  0.288075        4
# Vermont        -1.471113 -1.736616 -2.619581 -1.165456        1
# Virginia        0.302362 -0.047363 -0.117368  0.049986        4
# Washington     -0.831232 -0.183554  0.548400  0.624697        4
# West Virginia  -0.351448 -1.107361 -1.974229 -1.465557        1
# Wisconsin      -1.311116 -1.629734  0.087585 -1.226380        1
# Wyoming        -0.078767  0.012951 -0.327262 -0.556219        4

# %% [markdown]
# ### Hierarchical Clustering

# %%
import scipy.cluster.hierarchy as sch

# %%
fig = plt.figure(figsize=(15,8))
dendrogram = sch.dendrogram(sch.linkage(dfSqrt, method ="average"))

# %% [markdown]
# The path was long and unforgiving but we seem to have found solace in 4 clusters as this also hints towards the same.

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hc1 = AgglomerativeClustering(n_clusters=4, affinity = 'euclidean', linkage = 'average')

# %%
dfSqrt
# Out:
#                   Murder   Assault  UrbanPop      Rape
# States
# Alabama         1.191064  0.825024 -0.470119  0.105167
# Alaska          0.607966  1.084703 -1.224569  2.192878
# Arizona         0.216395  1.366910  0.987602  1.078481
# Arkansas        0.365517  0.345672 -1.067808 -0.085234
# California      0.407024  1.204970  1.640610  1.890787
# Colorado        0.172615  0.497173  0.864147  1.738357
# Connecticut    -1.058340 -0.655392  0.801826 -1.180584
# Delaware       -0.300030  0.844753  0.483966 -0.530722
# Florida         1.551524  1.718190  0.987602  1.159549
# Georgia         1.857432  0.570972 -0.327262  0.585070
# Hawaii         -0.457064 -1.780922  1.169927 -0.005866
# Idaho          -1.311116 -0.513746 -0.763424 -0.739477
# Illinois        0.685512  0.951811  1.169927  0.402827
# Indiana         0.014846 -0.612245  0.019795  0.083174
# Iowa           -1.471113 -1.568015 -0.542472 -1.150396
# Kansas         -0.274648 -0.583799  0.087585 -0.260253
# Kentucky        0.548783 -0.669904 -0.914152 -0.467676
# Louisiana       1.551524  0.951811  0.087585  0.213612
# Maine          -1.513340 -1.073819 -0.990603 -1.724936
# Maryland        0.854712  1.419782  0.154863  0.780255
# Massachusetts  -0.710356 -0.133451  1.289651 -0.467676
# Michigan        0.999537  1.009211  0.612395  1.438906
# Minnesota      -1.273082 -1.263693  0.087585 -0.646771
# Mississippi     1.660734  1.047102 -1.548212 -0.368782
# Missouri        0.407024  0.211309  0.353741  0.818440
# Montana        -0.274648 -0.669904 -0.838432 -0.455184
# Nebraska       -0.740042 -0.773414 -0.186766 -0.442729
# Nevada          1.017299  0.980596  1.048751  2.305521
# New Hampshire  -1.513340 -1.547812 -0.615462 -1.432605
# New Jersey      0.060677 -0.011061  1.524945 -0.166039
# New Mexico      0.873090  1.286579  0.353741  1.177408
# New York        0.817712  0.999691  1.348984  0.614819
# North Carolina  1.156852  1.734760 -1.465967 -0.492777
# North Dakota   -2.200214 -1.803435 -1.548212 -1.816867
# Ohio            0.037840 -0.513746  0.675958  0.127057
# Oklahoma       -0.126606 -0.108652  0.221642 -0.028400
# Oregon         -0.566747 -0.011061  0.154863  0.922074
# Pennsylvania   -0.199746 -0.713846  0.483966 -0.646771
# Rhode Island   -1.024513  0.165520  1.407974 -1.635907
# South Carolina  1.391108  1.232319 -1.224569  0.245666
# South Dakota   -0.893938 -1.024256 -1.465967 -0.932014
# Tennessee       1.191064  0.323580 -0.398388  0.693322
# Texas           1.105037  0.465157  0.987602  0.555149
# Utah           -1.092684 -0.513746  0.987602  0.288075
# Vermont        -1.471113 -1.736616 -2.619581 -1.165456
# Virginia        0.302362 -0.047363 -0.117368  0.049986
# Washington     -0.831232 -0.183554  0.548400  0.624697
# West Virginia  -0.351448 -1.107361 -1.974229 -1.465557
# Wisconsin      -1.311116 -1.629734  0.087585 -1.226380
# Wyoming        -0.078767  0.012951 -0.327262 -0.556219

# %%
cluster_pred2 = hc1.fit_predict(dfSqrt)
# Out:
# /home/its_relative/.local/lib/python3.10/site-packages/sklearn/cluster/_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
dfHier = dfSqrt.copy()
dfHier["Cluster"] = cluster_pred2

# %%
dfHier["Cluster"] = dfHier["Cluster"].apply(lambda x :x+1)
dfHier
# Out:
#                   Murder   Assault  UrbanPop      Rape  Cluster
# States
# Alabama         1.191064  0.825024 -0.470119  0.105167        1
# Alaska          0.607966  1.084703 -1.224569  2.192878        4
# Arizona         0.216395  1.366910  0.987602  1.078481        1
# Arkansas        0.365517  0.345672 -1.067808 -0.085234        2
# California      0.407024  1.204970  1.640610  1.890787        1
# Colorado        0.172615  0.497173  0.864147  1.738357        1
# Connecticut    -1.058340 -0.655392  0.801826 -1.180584        2
# Delaware       -0.300030  0.844753  0.483966 -0.530722        2
# Florida         1.551524  1.718190  0.987602  1.159549        1
# Georgia         1.857432  0.570972 -0.327262  0.585070        1
# Hawaii         -0.457064 -1.780922  1.169927 -0.005866        2
# Idaho          -1.311116 -0.513746 -0.763424 -0.739477        2
# Illinois        0.685512  0.951811  1.169927  0.402827        1
# Indiana         0.014846 -0.612245  0.019795  0.083174        2
# Iowa           -1.471113 -1.568015 -0.542472 -1.150396        3
# Kansas         -0.274648 -0.583799  0.087585 -0.260253        2
# Kentucky        0.548783 -0.669904 -0.914152 -0.467676        2
# Louisiana       1.551524  0.951811  0.087585  0.213612        1
# Maine          -1.513340 -1.073819 -0.990603 -1.724936        3
# Maryland        0.854712  1.419782  0.154863  0.780255        1
# Massachusetts  -0.710356 -0.133451  1.289651 -0.467676        2
# Michigan        0.999537  1.009211  0.612395  1.438906        1
# Minnesota      -1.273082 -1.263693  0.087585 -0.646771        3
# Mississippi     1.660734  1.047102 -1.548212 -0.368782        1
# Missouri        0.407024  0.211309  0.353741  0.818440        1
# Montana        -0.274648 -0.669904 -0.838432 -0.455184        2
# Nebraska       -0.740042 -0.773414 -0.186766 -0.442729        2
# Nevada          1.017299  0.980596  1.048751  2.305521        1
# New Hampshire  -1.513340 -1.547812 -0.615462 -1.432605        3
# New Jersey      0.060677 -0.011061  1.524945 -0.166039        2
# New Mexico      0.873090  1.286579  0.353741  1.177408        1
# New York        0.817712  0.999691  1.348984  0.614819        1
# North Carolina  1.156852  1.734760 -1.465967 -0.492777        1
# North Dakota   -2.200214 -1.803435 -1.548212 -1.816867        3
# Ohio            0.037840 -0.513746  0.675958  0.127057        2
# Oklahoma       -0.126606 -0.108652  0.221642 -0.028400        2
# Oregon         -0.566747 -0.011061  0.154863  0.922074        2
# Pennsylvania   -0.199746 -0.713846  0.483966 -0.646771        2
# Rhode Island   -1.024513  0.165520  1.407974 -1.635907        2
# South Carolina  1.391108  1.232319 -1.224569  0.245666        1
# South Dakota   -0.893938 -1.024256 -1.465967 -0.932014        3
# Tennessee       1.191064  0.323580 -0.398388  0.693322        1
# Texas           1.105037  0.465157  0.987602  0.555149        1
# Utah           -1.092684 -0.513746  0.987602  0.288075        2
# Vermont        -1.471113 -1.736616 -2.619581 -1.165456        3
# Virginia        0.302362 -0.047363 -0.117368  0.049986        2
# Washington     -0.831232 -0.183554  0.548400  0.624697        2
# West Virginia  -0.351448 -1.107361 -1.974229 -1.465557        3
# Wisconsin      -1.311116 -1.629734  0.087585 -1.226380        3
# Wyoming        -0.078767  0.012951 -0.327262 -0.556219        2

# %% [markdown]
# Let us apply DBSCAN now and end this once and for all

# %% [markdown]
# ### DBSCAN

# %%
dfDB = dfSqrt.copy()

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN()
