#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999891  0.999885  0.999775   0.999579 -0.334273
# High       0.999891  1.000000  0.999852  0.999910   0.999682 -0.332689
# Low        0.999885  0.999852  1.000000  0.999902   0.999746 -0.335508
# Close      0.999775  0.999910  0.999902  1.000000   0.999807 -0.333931
# Adj Close  0.999579  0.999682  0.999746  0.999807   1.000000 -0.328822
# Volume    -0.334273 -0.332689 -0.335508 -0.333931  -0.328822  1.000000

# %%
stock.shape
# Out:
# (5995, 7)

# %%
stock.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5990    False
# 5991    False
# 5992    False
# 5993    False
# 5994    False
# Length: 5995, dtype: bool

# %%
stock[stock.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
stock.isnull()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 5990  False  False  False  False  False      False   False
# 5991  False  False  False  False  False      False   False
# 5992  False  False  False  False  False      False   False
# 5993  False  False  False  False  False      False   False
# 5994  False  False  False  False  False      False   False
#
# [5995 rows x 7 columns]

# %%
stock.isnull().any(axis = 0)
# Out:
# Date         False
# Open          True
# High          True
# Low           True
# Close         True
# Adj Close     True
# Volume        True
# dtype: bool

# %%
stock[stock.isnull().any(axis=1)].shape[0]
# Out:
# 10

# %%
stock.dropna(inplace=True)

# %%
stock['Open'].hist()
# Out:
# <Axes: >

# %%
stock['High'].hist()
# Out:
# <Axes: >

# %%
stock['Close'].hist()
# Out:
# <Axes: >

# %%
#since all the null values where those days where the market was close due to weekend holidays,So removing those rows from the dataset won't make any difference.
stock[stock.isnull().any(axis=1)].shape[0]
# Out:
# 0

# %%
pd.plotting.scatter_matrix(stock)
# Out:
# array([[<Axes: xlabel='Open', ylabel='Open'>,
#         <Axes: xlabel='High', ylabel='Open'>,
#         <Axes: xlabel='Low', ylabel='Open'>,
#         <Axes: xlabel='Close', ylabel='Open'>,
#         <Axes: xlabel='Adj Close', ylabel='Open'>,
#         <Axes: xlabel='Volume', ylabel='Open'>],
#        [<Axes: xlabel='Open', ylabel='High'>,
#         <Axes: xlabel='High', ylabel='High'>,
#         <Axes: xlabel='Low', ylabel='High'>,
#         <Axes: xlabel='Close', ylabel='High'>,
#         <Axes: xlabel='Adj Close', ylabel='High'>,
#         <Axes: xlabel='Volume', ylabel='High'>],
#        [<Axes: xlabel='Open', ylabel='Low'>,
#         <Axes: xlabel='High', ylabel='Low'>,
#         <Axes: xlabel='Low', ylabel='Low'>,
#         <Axes: xlabel='Close', ylabel='Low'>,
#         <Axes: xlabel='Adj Close', ylabel='Low'>,
#         <Axes: xlabel='Volume', ylabel='Low'>],
#        [<Axes: xlabel='Open', ylabel='Close'>,
#         <Axes: xlabel='High', ylabel='Close'>,
#         <Axes: xlabel='Low', ylabel='Close'>,
#         <Axes: xlabel='Close', ylabel='Close'>,
#         <Axes: xlabel='Adj Close', ylabel='Close'>,
#         <Axes: xlabel='Volume', ylabel='Close'>],
#        [<Axes: xlabel='Open', ylabel='Adj Close'>,
#         <Axes: xlabel='High', ylabel='Adj Close'>,
#         <Axes: xlabel='Low', ylabel='Adj Close'>,
#         <Axes: xlabel='Close', ylabel='Adj Close'>,
#         <Axes: xlabel='Adj Close', ylabel='Adj Close'>,
#         <Axes: xlabel='Volume', ylabel='Adj Close'>],
#        [<Axes: xlabel='Open', ylabel='Volume'>,
#         <Axes: xlabel='High', ylabel='Volume'>,
#         <Axes: xlabel='Low', ylabel='Volume'>,
#         <Axes: xlabel='Close', ylabel='Volume'>,
#         <Axes: xlabel='Adj Close', ylabel='Volume'>,
#         <Axes: xlabel='Volume', ylabel='Volume'>]], dtype=object)

# %%
sns.pairplot(stock)
# Out:
# C:\Users\ankit\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
